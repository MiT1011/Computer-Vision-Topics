# %% [markdown]
# <a href="https://colab.research.google.com/github/MiT1011/Computer-Vision-Topics/blob/main/1_DigitalImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Taking user inputs for R, G and B
R = int(input("Enter R value: "))
G = int(input("Enter G value: "))
B = int(input("Enter B value: "))
# Constraining the values to the range 0 to 1
R_dash = R / 255
G_dash = G / 255
B_dash = B / 255
Cmax = max(R_dash, G_dash, B_dash)
Cmin = min(R_dash, G_dash, B_dash)
delta = Cmax - Cmin

# hue calculation
if (delta == 0):
  H = 0
elif (Cmax == R_dash):
  H = (60 * (((G_dash  - B_dash) / delta) % 6))
elif (Cmax == G_dash):
  H = (60 * (((B_dash  - R_dash) / delta) + 2))
elif (Cmax == B_dash):
  H = (60 * (((R_dash  - G_dash) / delta) + 4))


# saturation calculation
if (Cmax == 0):
  S = 0
else:
  S = delta / Cmax

# value calculation
V = Cmax

# print output. H in degrees. S and V in percentage.
# these values may also be represented from 0 to 255.
print("H = {:.1f}%".format(H * 100))
print("S = {:.1f}%".format(S * 100))
print("V = {:.1f}%".format(V * 100))
# Out:
# Enter R value: 255
# Enter G value: 255
# Enter B value: 255
# H = 0.0%
# S = 0.0%
# V = 100.0%

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import colorsys

# Open an RGB image
image_path = "/content/drive/MyDrive/FaceDetectionImage.jpg"
img = Image.open(image_path)
img_array = np.array(img)

plt.figure(figsize=(10, 5))
plt.subplot(2, 3, 1)
plt.imshow(img_array)
plt.title("Original RGB Image")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
red_channel = img_array[:, :, 0]
green_channel = img_array[:, :, 1]
blue_channel = img_array[:, :, 2]
plt.subplot(2, 3, 2)
plt.imshow(red_channel, cmap='Reds')
plt.title("Red Channel")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
plt.subplot(2, 3, 3)
plt.imshow(green_channel, cmap='Greens')
plt.title("Green Channel")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
plt.subplot(2, 3, 4)
plt.imshow(blue_channel, cmap='Blues')
plt.title("Blue Channel")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
#Convert to HSV and plotting
img_hsv = img.convert('HSV')
img_hsv_array = np.array(img_hsv)
plt.subplot(2, 3, 5)
plt.imshow(img_hsv_array)
plt.title("HSV Image")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
hue_channel = img_hsv_array[:, :, 0]
saturation_channel = img_hsv_array[:, :, 1]
value_channel = img_hsv_array[:, :, 2]
plt.subplot(2, 3, 6)
plt.imshow(hue_channel, cmap='hsv')
plt.title("Hue Component")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
plt.subplot(2, 3, 6)
plt.imshow(saturation_channel, cmap='gray')
plt.title("Saturation Component")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
plt.subplot(2, 3, 6)
plt.imshow(value_channel, cmap='gray')
plt.title("Value Component")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
img_cmyk = img.convert('CMYK')
img_cmyk_array = np.array(img_cmyk)
plt.figure(figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.imshow(img_cmyk_array)
plt.title("CMYK Image")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
cyan_channel = img_cmyk_array[:, :, 0]
magenta_channel = img_cmyk_array[:, :, 1]
yellow_channel = img_cmyk_array[:, :, 2]
black_channel = img_cmyk_array[:, :, 3]
plt.subplot(1, 4, 2)
plt.imshow(cyan_channel, cmap='Blues')
plt.title("Cyan Component")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
plt.subplot(1, 4, 3)
plt.imshow(magenta_channel, cmap='Reds')
plt.title("Magenta Component")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
plt.subplot(1, 4, 4)
plt.imshow(yellow_channel, cmap='Greens')
plt.title("Yellow Component")
plt.axis('off')
# Out:
# (-0.5, 1151.5, 729.5, -0.5)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import colorsys
import cv2
from google.colab.patches import cv2_imshow

image1 = "/content/drive/MyDrive/CV IMAGES/v1.jpg"
image2 = "/content/drive/MyDrive/CV IMAGES/v10.jpg"
image3 = "/content/drive/MyDrive/CV IMAGES/v13.jpg"
img1 = Image.open(image1)
img2 = Image.open(image2)
img3 = Image.open(image3)

img_array1 = np.array(img1)
img_array2 = np.array(img2)
img_array3 = np.array(img3)

plt.figure(figsize=(10, 5))
plt.subplot(2, 3, 1)
plt.imshow(img_array1)


plt.figure(figsize=(10, 5))
plt.subplot(2, 3, 1)
plt.imshow(img_array2)


plt.figure(figsize=(10, 5))
plt.subplot(2, 3, 1)
plt.imshow(img_array3)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import colorsys
import cv2
from google.colab.patches import cv2_imshow

image_1 = cv2.imread("/content/drive/MyDrive/CV IMAGES/v1.jpg")
cv2_imshow(image_1)
grayscale_image1 = cv2.cvtColor(image_1, cv2.COLOR_BGR2GRAY)
cv2_imshow(grayscale_image1)
hist1 = cv2.calcHist([grayscale_image1], [0], None, [256], [0, 256])
plt.plot(hist1, color='black')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()


image_2 = cv2.imread("/content/drive/MyDrive/CV IMAGES/v10.jpg")
cv2_imshow(image_2)
grayscale_image2 = cv2.cvtColor(image_2, cv2.COLOR_BGR2GRAY)
cv2_imshow(grayscale_image2)
hist2 = cv2.calcHist([grayscale_image2], [0], None, [256], [0, 256])
plt.plot(hist2, color='black')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()


image_3 = cv2.imread("/content/drive/MyDrive/CV IMAGES/v13.jpg")
cv2_imshow(image_3)
grayscale_image3 = cv2.cvtColor(image_3, cv2.COLOR_BGR2GRAY)
cv2_imshow(grayscale_image3)
hist3 = cv2.calcHist([grayscale_image3], [0], None, [256], [0, 256])
plt.plot(hist3, color='black')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=626x417>
# <PIL.Image.Image image mode=L size=626x417>
# <PIL.Image.Image image mode=RGB size=1152x730>
# <PIL.Image.Image image mode=L size=1152x730>
# <PIL.Image.Image image mode=RGB size=338x338>
# <PIL.Image.Image image mode=L size=338x338>
